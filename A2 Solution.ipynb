# %% [markdown]
# ---
# # Cairo University Faculty of Engineering
# ## Deep Learning
# ## Assignment 2
#
# ---

# %% [markdown]
# Please write your full name here
# - **Name** : "Ahmed Hossam Aldeen"

# %%
# !mkdir d2l

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from d2l import tensorflow as d2l
import pandas as pd
import math

from sklearn.datasets import make_blobs  #To generate artificial data
from keras.optimizers import SGD
from keras.utils import to_categorical

# %% [markdown]
# # Part 1 Computational Graphs

# %% [markdown]
# ## Example
# Suppose that we have a function of the form: $f(x,y) = \sigma(x) + (x-y)^2$

# %% [markdown]
# **SHOW YOUR WORK**

# %% [markdown]
# 0. **Draw its computational graph with a minimum of 4 operations inside it. Name your intermediate variables and upload a picture of your graph**

# %% [markdown]
# - Your Answer:
#     ![Answer](data:image/jpeg;base64,...)

# %% [markdown]
# 1. **Compute the forward path for this function. Use intermediate variables you identified in your graph**
#
# - f --> final output
# - Upload a a picture of your graph

# %% [markdown]
# - Your Answer: ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. **Compute the backward path for this function to get:**
# $$
# \nabla f(x,y) = [ \frac{\partial f}{\partial y}, \frac{\partial f}{\partial x} ]
# $$
#
# - Upload a a picture of your graph
# - **Use intermediate variables**
# - **Write df/dy and df/dx**
# - *Hint: Gradients add up at forks. This follows the multivariable chain rule in Calculus, which states that if a variable branches out to different parts, then the gradients that flow back to it will add.*

# %% [markdown]
# - Your Answer: ![3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Part 2: Regression

# %% [markdown]
# In this part, (**we will implement the entire linear regression method from scratch,
# including the data pipeline, the model,
# the loss function, and the minibatch stochastic gradient descent optimizer.**)
# You will rely only on tensors and auto differentiation.

# %% [markdown]
# we will use $n$ to denote
# the number of examples in our dataset.
# We index the data examples by $i$, denoting each input
# as $\mathbf{x}^{(i)} = [x_1^{(i)}, x_2^{(i)}]^\top$
# and the corresponding label as $y^{(i)}$.
#
#
# **Linear Model**
#
# When our inputs consist of $d$ features,
# we express our prediction $\hat{y}$ (in general the "hat" symbol denotes estimates) as
#
# $$\hat{y} = w_1  x_1 + ... + w_d  x_d + b.$$
#
#
# We will often find it convenient
# to refer to features of our entire dataset of $n$ examples
# via the *design matrix* $\mathbf{X} \in \mathbb{R}^{n \times d}$.
# Here, $\mathbf{X}$ contains one row for every example
# and one column for every feature.
#
# For a collection of features $\mathbf{X}$,
# the predictions $\hat{\mathbf{y}} \in \mathbb{R}^n$
# can be expressed via the matrix-vector product:
#
# $${\hat{\mathbf{y}}} = \mathbf{X} \mathbf{w} + b,$$
#
#
# **Loss Function**
#
# When our prediction for an example $i$ is $\hat{y}^{(i)}$
# and the corresponding true label is $y^{(i)}$,
# the squared error is given by:
#
# $$l^{(i)}(\mathbf{w}, b) = \frac{1}{2} \left(\hat{y}^{(i)} - y^{(i)}\right)^2.$$
#
# To measure the quality of a model on the entire dataset of $n$ examples,
# we simply average (or equivalently, sum)
# the losses on the training set.
#
# $$L(\mathbf{w}, b) =\frac{1}{n}\sum_{i=1}^n l^{(i)}(\mathbf{w}, b) =\frac{1}{n} \sum_{i=1}^n \frac{1}{2}\left(\mathbf{w}^\top \mathbf{x}^{(i)} + b - y^{(i)}\right)^2.$$
#
# When training the model, we want to find parameters ($\mathbf{w}^*, b^*$)
# that minimize the total loss across all training examples:
#
# $$\mathbf{w}^*, b^* = \operatorname*{argmin}_{\mathbf{w}, b}\  L(\mathbf{w}, b).$$

# %% [markdown]
# **Minibatch Stochastic Gradient Descent**
#
# We can express the update mathematically as follows
# ($\partial$ denotes the partial derivative):
#
# $$(\mathbf{w},b) \leftarrow (\mathbf{w},b) - \frac{\eta}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} \partial_{(\mathbf{w},b)} l^{(i)}(\mathbf{w},b).$$

# %% [markdown]
# ## Synthetic Data, Simple Model
# ### Generating the Dataset
#
# To keep things simple, we will [**construct an artificial dataset
# according to a linear model with additive noise.**]
#
# In the following code snippet, we generate a dataset
# containing 1000 examples, each consisting of 2 features
# sampled from a standard normal distribution.
# Thus our synthetic dataset will be a matrix
# $\mathbf{X}\in \mathbb{R}^{1000 \times 2}$.
#
# (**The true parameters generating our dataset will be
# $\mathbf{w} = [2, -3.4]^\top$ and $b = 4.2$,
# and**) our synthetic labels will be assigned according
# to the following linear model with the noise term $\epsilon$:
#
# (**$$\mathbf{y}= \mathbf{X} \mathbf{w} + b + \mathbf\epsilon.$$**)

# %%
def synthetic_data(w, b, num_examples):  #@save
    """Generate y = Xw + b + noise."""
    X = tf.zeros((num_examples, w.shape[0]))
    X += tf.random.normal(shape=X.shape)
    y = tf.matmul(X, tf.reshape(w, (-1, 1))) + b
    y += tf.random.normal(shape=y.shape, stddev=0.01)
    y = tf.reshape(y, (-1, 1))
    return X, y

# %%
tf.random.set_seed(5)
true_w = tf.constant([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %%
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# features: tf.Tensor([-0.18030666 -0.95028627], shape=(2,), dtype=float32)
# label: tf.Tensor([7.0726256], shape=(1,), dtype=float32)

# %% [markdown]
# By generating a scatter plot using the second feature `features[:, 1]` and `labels`,
# we can clearly observe the linear correlation between the two.

# %%
d2l.set_figsize()
# The semicolon is for displaying the plot only
d2l.plt.scatter(features[:, (1)].numpy(), labels.numpy(), 1);

# %% [markdown]
# ### Reading the Dataset
#
# In the following code [**call upon the existing API in a framework to read data.**]
# We pass in `features` and `labels` as arguments and specify `batch_size`
# when instantiating a data iterator object.
# Besides, the boolean value `is_train`
# indicates whether or not
# we want the data iterator object to shuffle the data
# on each epoch (pass through the dataset).

# %% [markdown]
# 1. **Use the tf function from_tensor_slices to generate a tf dataset object with batch_size as input**
# 2. **Use is_train flag to determine whether to shuffle the dataset or not**

# %%
import random

def load_array(data_arrays, batch_size, is_train=True):  #@save
    """Construct a TensorFlow data iterator."""
    dataset = tf.data.Dataset.from_tensor_slices(data_arrays)

    if(is_train):
        dataset = dataset.batch(batch_size).shuffle(random.randint(0, 1000))
    else:  
        dataset = dataset.batch(batch_size)
    return dataset

# %%
batch_size = 10
data_iter = load_array((features, labels), batch_size)

# %% [markdown]
# 3. **Use `iter` to construct a Python iterator and use `next` to obtain the first item from the iterator.**

# %%
### YOUR CODE HERE ###
np_iter = data_iter.as_numpy_iterator()
print(np_iter.next())
# Out:
# (array([[ 1.3564042e+00, -5.4133564e-01],
#        [-1.0421329e+00,  2.0101455e-01],
#        [-5.7323533e-01,  9.6179825e-01],
#        [ 9.9003547e-01, -1.0166390e+00],
#        [-2.7223307e-01, -4.9159122e-01],
#        [-8.1928289e-01, -9.0086297e-04],
#        [-2.0796096e+00,  8.4328723e-01],
#        [ 3.0477965e-01,  2.0460723e-01],
#        [ 1.1995399e+00,  2.9454825e+00],
#        [-5.4580241e-01, -6.5089208e-01]], dtype=float32), array([[ 8.755783  ],
#        [ 1.4219627 ],
#        [-0.21046364],
#        [ 9.629394  ],
#        [ 5.3383512 ],
#        [ 2.5792086 ],
#        [-2.8150222 ],
#        [ 4.1173363 ],
#        [-3.4104102 ],
#        [ 5.3102717 ]], dtype=float32))

# %% [markdown]
# 4. **Explain what the output shape in the prvious tensors means:**
#
# We have 1000 samples so with batch_size=10 we have 100 batches each batch contains 10 samples

# %% [markdown]
# **Answer:**

# %% [markdown]
# 5. **How many TOTAL batches can be generated by **ENTIRE** data_iter ?** --> batches in data

# %% [markdown]
# **Answer:** 100 batches each batch contains 10 samples

# %% [markdown]
# ### Initializing Model Parameters
#
# 6. **Initialize weights by sampling random numbers from a normal distribution with mean 0 and a standard deviation of 0.01, and setting the bias to 0.**
#
# Note: For the shapes of the weights and bias, look at the generating a dataset part

# %%
## YOUR CODE HERE ##
num_inputs = 2
num_outputs = 1

w = tf.Variable(tf.random.normal(shape=(num_inputs, num_outputs),mean=0, stddev=0.01))
b = tf.Variable(tf.zeros(num_outputs))

print(w)
print(b)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 1) dtype=float32, numpy=
# array([[0.00037003],
#        [0.00345929]], dtype=float32)>
# <tf.Variable 'Variable:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>

# %% [markdown]
# ### Defining the Model
#
# 7. [**define our model, relating its inputs and parameters to its outputs.**]

# %%
def linreg(X, w, b):  
    """The linear regression model."""
    ## YOUR CODE HERE ##
    model = tf.linalg.matmul(X,w) + b
    return model

# %% [markdown]
# ### Defining the Loss Function
#
# 8. (**define the loss function**): the squared loss function
# as described in Loss Function definition above.
#
# Note: In the implementation, you need to transform the true value `y`
# into the predicted value's shape `y_hat`.
# The result returned by the following function
# will also have the same shape as `y_hat`.

# %%
def squared_loss(y_hat, y):  
    """Squared loss."""
    ## YOUR CODE HERE ##
    loss = tf.reduce_mean(tf.square(y-y_hat))
    return loss

# %% [markdown]
# ### Defining the Optimization Algorithm
#
# At each step, using one minibatch randomly drawn from our dataset,
# we will estimate the gradient of the loss with respect to our parameters.
# Next, we will update our parameters
# in the direction that may reduce the loss.
#
# 9. **Filll in the missing function below to apply the minibatch stochastic gradient descent update, given a set of parameters, a learning rate, and a batch size.**
#
# Note: use assign_sub

# %%
def sgd(params, grads, lr, batch_size):  
    """Minibatch stochastic gradient descent."""
    
    ## YOUR CODE HERE ##
    for param, grad in zip(params, grads):
        # Subtracts a value from this variable.
        param.assign_sub(lr*grad/batch_size)

# %% [markdown]
# ### Training
#
# 10. **Implement the following loop**
#
# * For each epoch :
#     * Initialize parameters $(\mathbf{w}, b)$
#     * Repeat until done
#         * Compute gradient $\mathbf{g} \leftarrow \partial_{(\mathbf{w},b)} \frac{1}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} l(\mathbf{x}^{(i)}, y^{(i)}, \mathbf{w}, b)$
#         * Update parameters $(\mathbf{w}, b) \leftarrow (\mathbf{w}, b) - \eta \mathbf{g}$
#     * Print the loss at the end of each epoch
#
# In each *epoch*,
# we will iterate through the entire dataset
# (using the `data_iter` function) once
# passing through every example in the training dataset
# .
#
#
# Set the number of epochs `num_epochs` and the learning rate `lr` to 3 and 0.03, respectively.

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

# %%
## YOUR CODE HERE ##
batch_size = 1

for i in range(0,num_epochs):
      for X,y in load_array((features, labels), batch_size):
            with tf.GradientTape(persistent=True) as tape:
                  l = squared_loss(linreg(X,w,b), y)
                  #print(l)
            dl_dw = tape.gradient(l,w)
            dl_db = tape.gradient(l,b)

            sgd([w,b],[dl_dw,dl_db],lr,batch_size)
      #print(f"Total loss after {i+1} epoch",squared_loss(linreg(X,w,b), y))
      print(f"Total loss after {i+1} epoch",squared_loss(linreg(features,w,b), labels))

print(" ")
print("Final w value: ", w)
print("Final b value: ", b)
# Out:
# Total loss after 1 epoch tf.Tensor(0.00013134557, shape=(), dtype=float32)
# Total loss after 2 epoch tf.Tensor(0.0001367979, shape=(), dtype=float32)
# Total loss after 3 epoch tf.Tensor(0.00013240891, shape=(), dtype=float32)
#
# Final w value:  <tf.Variable 'Variable:0' shape=(2, 1) dtype=float32, numpy=
# array([[ 1.9964381],
#        [-3.4009867]], dtype=float32)>
# Final b value:  <tf.Variable 'Variable:0' shape=(1,) dtype=float32, numpy=array([4.198076], dtype=float32)>

# %% [markdown]
# In this case, because we synthesized the dataset ourselves,
# we know precisely what the true parameters are.
#
# 11. [**evaluate our success in training by comparing the true parameters with those that we learned**] through our training loop. They should turn out to be very close to each other.

# %%
## YOUR CODE HERE ##
print(f'error in estimating w: {abs(w-[ [2] , [-3.4] ])}')
print(f'error in estimating b: {abs(b-4.2)}')
# Out:
# error in estimating w: [[0.00356185]
#  [0.00098658]]
# error in estimating b: [0.00192404]

# %% [markdown]
# ## Part 2  Diabetes Dataset

# %% [markdown]
# In this section, we will use SKLEARN's Diabetes dataset

# %% [markdown]
# ### Loading the Dataset

# %% [markdown]
# 1. **Load the Diabetes dataset from sklearn**

# %%
from sklearn.datasets import load_diabetes
## YOUR CODE HERE ##
# Load the diabetes dataset
diabetes =load_diabetes()

# %% [markdown]
# 2. **Look at the keys of diabetes_dataset dictionary**

# %%
## YOUR CODE HERE ##
### Look at keys to determine the data
print(list(diabetes))
# Out:
# ['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module']

# %% [markdown]
# 3. **Use the key DESCR to understand the dataset**

# %%
## YOUR CODE HERE ##
print(diabetes['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %% [markdown]
# 4. **Save the data and target variables in numpy arrays and print their shapes**

# %%
### START CODE HERE ### (≈ 2 lines of code)
data = np.array(diabetes['data'])
targets = np.array(diabetes['target'])
### END CODE HERE ###

print ('The shape of data is: ' + str(data.shape))
print ('The shape of targets is: ' + str(targets.shape))
print ('I have f = %d features!' % (data.shape[1]))
print ('I have m = %d examples!' % (data.shape[0]))
# Out:
# The shape of data is: (442, 10)
# The shape of targets is: (442,)
# I have f = 10 features!
# I have m = 442 examples!

# %% [markdown]
# 5. **What are the ranges of each column in features and the target column?**
#     - *Hint* you might find it helpful to convert to pandas dataframe and use ".describe"

# %%
### START CODE HERE ###
df_diabetes = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df_diabetes['target'] = pd.Series(diabetes.target)
df_diabetes.describe()
### END CODE HERE ###
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.639623e-16  1.309912e-16 -8.013951e-16  1.289818e-16 -9.042540e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.301121e-16 -4.563971e-16  3.863174e-16 -3.848103e-16 -3.398488e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#            target
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# 6. **Split the data into train and test set using sklearn train_test_split.** Have the test set as 10% of data

# %%
np.random.seed(0)
### START CODE HERE ###
from sklearn.model_selection import train_test_split
train_data, test_data, train_targets, test_targets = train_test_split( data,targets, test_size=0.10, random_state=np.random.seed(0))
### END CODE HERE ###

print("Shape of training data is", train_data.shape)
print("Shape of training targets is", train_targets.shape)
print("Shape of test data is", test_data.shape)
print("Shape of test targets is", test_targets.shape)
# Out:
# Shape of training data is (397, 10)
# Shape of training targets is (397,)
# Shape of test data is (45, 10)
# Shape of test targets is (45,)

# %% [markdown]
# - *feature-wise normalization*: for each feature in the input data (a column in the input data matrix), we subtract the mean of the feature and divide by the standard deviation, so that the feature is centered around 0 and has a unit standard deviation. This is easily done in NumPy.
# - **Question:** Shold we normalize features? WHY?
#     - ANSWER: No, Because the ranges between features are very small so we don't need to normalize the features.
# We only need to normalize the targets

# %% [markdown]
# 7. **normalize the targets using standard normalization**
#
# Hint: Avoid leak between train and test data !!

# %%
### START CODE HERE ### (≈ 6 lines of code)

normalized_train_targets = []
normalized_test_targets = []

for i in train_targets:
  normalized_train_targets.append((i - np.mean(train_targets)) / np.std(train_targets))

for j in test_targets:
  normalized_test_targets.append((j - np.mean(test_targets)) / np.std(test_targets))


print(normalized_train_targets)
print(normalized_test_targets)

### END CODE HERE ###
# Out:
# [-0.794999716245709, 0.8140981269182236, 0.4021690790682569, -0.8593636299722663, 1.5349739606556654, 0.06747672769015889, -0.16423336172544742, -0.48605293035823394, -0.25434284094262766, 0.5695152547573059, 0.2605684688698308, -0.37019788565043077, -1.1554376331144298, 1.020062650843207, 1.0844265645697644, -1.271292677822233, -0.3830706683957422, -0.08699666525357864, -0.5632896268301028, -0.24147005819731618, 1.9469030085056322, -1.2584198950769216, 2.1399947496853042, -0.17710614447075887, -1.2069287640956758, -0.6791446715379058, 0.24769568612451934, -0.8078724989910204, -0.7821269335003975, -1.0782009366425611, 0.15758620690733913, -0.6019079750660371, 0.45366021004950274, 0.376423513577634, 1.7023201363447145, -0.125615013489513, -0.009759968781709875, -1.3356565915487904, 1.882539094779075, -0.6019079750660371, -1.3099110260581674, -0.6147807578113486, -0.11274223074420156, -1.181183198605053, -0.8464908472269549, -0.17710614447075887, -1.2584198950769216, -1.2841654605675445, 0.5952608202479288, -0.2028517099613818, -1.0138370229160039, 0.7368614304463549, 1.1101721300603873, -0.07412388250826718, -0.5246712785941683,
# [2.2525688801747763, 0.7291386294398148, -0.5355959183401533, -1.4410308786826305, 0.15425928953982926, 1.591457639289793, 0.2117472235298278, 0.9734623488973085, -0.3200161658776588, -0.9380114562701432, 1.2609020188473012, 0.1398873060423296, -0.506851951345154, -1.297311043707634, 1.433365820817297, -1.656610631145125, -1.1248472417376385, -1.2829390602101345, -0.9092674892751439, -0.1331803804101635, 0.08239937205233107, 1.6058296227872926, -0.7799196377976472, -0.4062480668626566, -1.383542944692632, -0.5212239348426537, -0.8805235222801446, -1.024243357255141, 0.38421102549982344, 0.45607094298732165, 0.757882596434814, 0.24049119052482706, 0.05365540505733179, 0.5135588769773202, 0.7866265634298133, 1.6776895402747907, -0.19066831440016205, 1.3327619363347996, -1.656610631145125, 0.4848149099823209, -0.9811274067626421, 0.2117472235298278, -0.9954993902601417, 0.4848149099823209, 1.1459261508673042]

# %% [markdown]
# ### Building your model

# %% [markdown]
# 7. **Use tf.keras.Sequential to build a model with:**
#     - 6 hidden layers each having 128 neurons and relu activation.
#     - 1 output layer
#     - use input_shape argument to specify input size in 1st layer
# - **Question:** How many neurons should be in output layer? What should be the activation?
#     - ANSWER: 1  , none

# %%
def build_model(input_shape):
    ### START CODE HERE ### ()

    ## Create our model
    model = Sequential()

    # 1st layer: input RELU
    model.add(Dense(128, input_dim=input_shape,  activation='relu'))
    # 2nd layer: 8 nodes, RELU
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    # output layer:
    model.add(Dense(1))

    return model

# %%
# Print the model summary
#input_shape=(train_data.shape[-1],)
input_shape=(train_data.shape[-1])
model = build_model(input_shape)
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 128)               1408
#
#  dense_29 (Dense)            (None, 128)               16512
#
#  dense_30 (Dense)            (None, 128)               16512
#
#  dense_31 (Dense)            (None, 128)               16512
#
#  dense_32 (Dense)            (None, 128)               16512
#
#  dense_33 (Dense)            (None, 128)               16512
#
#  dense_34 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 84,097
# Trainable params: 84,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 8. **Compile the model using optimizer=Adam, loss=mean squared loss, metrics=mean absoluute error:**

# %%
### START CODE HERE ### ()
model.compile(loss='mse',
             optimizer='adam',
             metrics=['mae'])

# %% [markdown]
# Note that we compile the model with the mse loss function—mean squared error, the
# square of the difference between the predictions and the targets. We’re also monitoring a new metric during training: mean absolute error (MAE). It’s the
# absolute value of the difference between the predictions and the targets.

# %% [markdown]
# 9. **FIT the model using for 100 epochs, 64 batch size and a validation split of 0.15**

# %%
### START CODE HERE ### ()
history = model.fit(train_data,
                    np.array(normalized_train_targets),
                    epochs=100,
                    validation_split=0.15,
                    batch_size=64)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 39ms/step - loss: 0.9563 - mae: 0.8396 - val_loss: 1.0952 - val_mae: 0.8921
# Epoch 2/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8817 - mae: 0.8085 - val_loss: 0.9138 - val_mae: 0.8295
# Epoch 3/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6955 - mae: 0.7259 - val_loss: 0.6370 - val_mae: 0.6731
# Epoch 4/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5243 - mae: 0.5969 - val_loss: 0.6834 - val_mae: 0.6311
# Epoch 5/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5411 - mae: 0.5788 - val_loss: 0.5556 - val_mae: 0.6184
# Epoch 6/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.
100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0413 - mae: 0.1541 - val_loss: 0.8040 - val_mae: 0.6134
# Epoch 98/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0483 - mae: 0.1681 - val_loss: 0.7800 - val_mae: 0.6066
# Epoch 99/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0488 - mae: 0.1698 - val_loss: 0.7707 - val_mae: 0.6048
# Epoch 100/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0512 - mae: 0.1784 - val_loss: 0.7566 - val_mae: 0.6003

# %%
# Evaluate the model on the test set
model.evaluate(test_data, np.array(normalized_test_targets), verbose=2)
# Out:
# 2/2 - 0s - loss: 0.8070 - mae: 0.7165 - 19ms/epoch - 9ms/step
# [0.8069963455200195, 0.7164914608001709]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plot the training and validation loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# 9. **Diagnose the learning curve:**
#     - Why is the validation loss much higher than training loss?
#     - What's this phenomenon called?
#     - Mention 3 methods to reduce this.

# %% [markdown]
# - **answer**:
#     - Because the model is overfitting as it's too deep and the number of neurons is very high
#     - Overfitting
#     - Adding Dropout Layer,
#       Reducing number of layers,
#       Reducing number of neurons

# %% [markdown]
# 10. **Use one of the methods you mentioned and retrain the model then plot the learning curves**

# %%
#### YOUR CODE HERE
###----------------------------Reducing number of layers-------------------------###
## Create our model
model = Sequential()

# 1st layer: input RELU
model.add(Dense(28, input_dim=input_shape,  activation='relu'))
# 2nd layer: 8 nodes, RELU
model.add(Dense(28, activation='relu'))
# output layer:
model.add(Dense(1))

model.compile(loss='mse',
             optimizer='adam',
             metrics=['mae'])

history = model.fit(train_data,
                    np.array(normalized_train_targets),
                    epochs=100,
                    validation_split=0.15,
                    batch_size=64)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 30ms/step - loss: 0.9586 - mae: 0.8389 - val_loss: 1.1402 - val_mae: 0.9055
# Epoch 2/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9435 - mae: 0.8313 - val_loss: 1.1249 - val_mae: 0.8977
# Epoch 3/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9282 - mae: 0.8235 - val_loss: 1.1075 - val_mae: 0.8899
# Epoch 4/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9112 - mae: 0.8153 - val_loss: 1.0868 - val_mae: 0.8816
# Epoch 5/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8924 - mae: 0.8068 - val_loss: 1.0636 - val_mae: 0.8718
# Epoch 6/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8725 - mae: 0.7975 - val_loss: 1.0366 - val_mae: 0.8609
# Epoch 7/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8489 - mae: 0.7861 - val_loss: 1.0075 - val_mae: 0.8493
# Epoch 8/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8237 - mae: 0.7741 - val_loss: 0.9723 - val_mae: 0.8348
# Epoch 9/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7945 - mae: 0.7602 - val_loss: 0.9336 - val_mae: 0.8180
# Epoch 10/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7622 - mae: 0.7444 - val_loss: 0.8921 - val_mae: 0.8009
# Epoch 11/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7272 - mae: 0.7274 - val_loss: 0.8476 - val_mae: 0.7803
# Epoch 12/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6916 - mae: 0.7074 - val_loss: 0.8013 - val_mae: 0.7588
# Epoch 13/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6583 - mae: 0.6918 - val_loss: 0.7557 - val_mae: 0.7385
# Epoch 14/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6268 - mae: 0.6745 - val_loss: 0.7174 - val_mae: 0.7169
# Epoch 15/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5994 - mae: 0.6564 - val_loss: 0.6794 - val_mae: 0.6957
# Epoch 16/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0
100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4430 - mae: 0.5368 - val_loss: 0.4973 - val_mae: 0.5710
# Epoch 83/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4424 - mae: 0.5369 - val_loss: 0.4995 - val_mae: 0.5721
# Epoch 84/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4424 - mae: 0.5366 - val_loss: 0.5005 - val_mae: 0.5710
# Epoch 85/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4428 - mae: 0.5359 - val_loss: 0.5015 - val_mae: 0.5710
# Epoch 86/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4425 - mae: 0.5368 - val_loss: 0.4991 - val_mae: 0.5718
# Epoch 87/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4415 - mae: 0.5363 - val_loss: 0.4990 - val_mae: 0.5706
# Epoch 88/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4409 - mae: 0.5360 - val_loss: 0.4959 - val_mae: 0.5707
# Epoch 89/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4438 - mae: 0.5386 - val_loss: 0.4954 - val_mae: 0.5704
# Epoch 90/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4387 - mae: 0.5338 - val_loss: 0.5058 - val_mae: 0.5700
# Epoch 91/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4458 - mae: 0.5348 - val_loss: 0.5094 - val_mae: 0.5708
# Epoch 92/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4456 - mae: 0.5375 - val_loss: 0.4985 - val_mae: 0.5728
# Epoch 93/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4406 - mae: 0.5358 - val_loss: 0.4981 - val_mae: 0.5724
# Epoch 94/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4397 - mae: 0.5354 - val_loss: 0.4944 - val_mae: 0.5689
# Epoch 95/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4392 - mae: 0.5343 - val_loss: 0.4928 - val_mae: 0.5672
# Epoch 96/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4405 - mae: 0.5343 - val_loss: 0.4947 - val_mae: 0.5651
# Epoch 97/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4402 - mae: 0.5318 - val_loss: 0.5029 - val_mae: 0.5662
# Epoch 98/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4421 - mae: 0.5329 - val_loss: 0.5010 - val_mae: 0.5669
# Epoch 99/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4398 - mae: 0.5325 - val_loss: 0.4966 - val_mae: 0.5668
# Epoch 100/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4369 - mae: 0.5322 - val_loss: 0.4939 - val_mae: 0.5676

# %%
# Plot the training and validation loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Part 3 Batches and Epochs

# %% [markdown]
# In this part of the assignment we will create a synthetic data to play with.
# The data will have 2 features and 3 target classes --> multiclass classification problem

# %%
# prepare train and test dataset
def prepare_data():
    #  generate classification dataset with 3 centers (labels/classes)
    X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)
    
    # plot data
    for class_value in range(3):
        # select indices of points with the class label
        row_ix = np.where(y == class_value)
        # scatter plot for points with a different color
        plt.scatter(X[row_ix, 0], X[row_ix, 1])
    # show plot
    plt.show()

    # one hot encode output variable to convert from integers to binary class
    y = to_categorical(y)

    # split into train and test
    n_train = 500
    X_train, X_test = X[:n_train, :], X[n_train:, :]
    y_train, y_test = y[:n_train], y[n_train:]
    return X_train, y_train, X_test, y_test

# %%
# prepare dataset
X_train, y_train, X_test, y_test = prepare_data()

# %% [markdown]
# - **Create a model with:**
#     -  1 hidden dense layer (50 neurons), activation relu, , kernel_initializer he_uniform
#     - 1 output layer
#     - compile the model with SGD (learning rate 0.01 and momentum 0.9) optimizer and categorical crossentropy and accuracy inside build function

# %%
def build_model():
    
    ##### YOUR CODE HERE
    # define model
    model = Sequential()

    # 1st layer
    model.add(Dense(50, kernel_initializer='he_uniform' ,  activation='relu'))

    # output layer
    model.add(Dense(3, activation='sigmoid'))

    # compile model
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
                   metrics=['accuracy'])
    
    return model

# %% [markdown]
# - Create a function to fit and build the model with different batch sizes

# %% [markdown]
# Use epochs = 125

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_test, y_test, n_batch):
    ##### YOUR CODE HERE
    # build model
    model = build_model()

    # fit model
    history = model.fit(X_train,
              y_train,
              validation_data=(X_test, y_test),
              batch_size = n_batch,
              epochs = 125
              )

    return history

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# #### Batch size

# %% [markdown]
# ##### Size =  1

# %% [markdown]
# 10. **train for 1 batch size**

# %%
### START CODE HERE ### 
batch_size = 1

history = fit_model(X_train, y_train, X_test, y_test, batch_size)
###### END CODE HERE
# Out:
# Epoch 1/125
# 500/500 [==============================] - 3s 5ms/step - loss: 1.6961 - accuracy: 0.5080 - val_loss: 0.9813 - val_accuracy: 0.4600
# Epoch 2/125
# 500/500 [==============================] - 2s 4ms/step - loss: 1.0489 - accuracy: 0.4920 - val_loss: 1.0882 - val_accuracy: 0.5640
# Epoch 3/125
# 500/500 [==============================] - 2s 5ms/step - loss: 1.0671 - accuracy: 0.5040 - val_loss: 0.9536 - val_accuracy: 0.5520
# Epoch 4/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.9887 - accuracy: 0.5120 - val_loss: 0.9745 - val_accuracy: 0.5340
# Epoch 5/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.9292 - accuracy: 0.5660 - val_loss: 0.6614 - val_accuracy: 0.7460
# Epoch 6/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.8259 - accuracy: 0.6080 - val_loss: 1.3185 - val_accuracy: 0.4480
# Epoch 7/125
# 500/500 [==============================] - 2s 5ms/step - loss: 1.0197 - accuracy: 0.5200 - val_loss: 0.8545 - val_accuracy: 0.5880
# Epoch 8/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.8930 - accuracy: 0.5900 - val_loss: 0.8638 - val_accuracy: 0.6600
# Epoch 9/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.8878 - accuracy: 0.6060 - val_loss: 0.7940 - val_accuracy: 0.6180
# Epoch 10/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.8466 - accuracy: 0.6460 - val_loss: 0.8293 - val_accuracy: 0.5700
# Epoch 11/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.8429 - accuracy: 0.6400 - val_loss: 1.0386 - val_accuracy: 0.5620
# Epoch 12/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.9132 - accuracy: 0.6320 - val_loss: 0.7517 - val_accuracy: 0.6880
# Epoch 13/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.9249 - accuracy: 0.5860 - val_loss: 0.8232 - val_accuracy: 0.5180
# Epoch 14/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.7955 - accuracy: 0.6220 - val_loss: 0.8071 - val_accuracy: 0.6740
# Epoch 15/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# - **Diagnose this curve w.r.t learning rate**:
#     - ANSWER: the learning rate is high so the model fluctuates and diverges and cant find global minima so we need to decrease the learning rate
# - Change learning rate to make this curve better

# %%
# define model
model = Sequential()

# 1st layer
model.add(Dense(50, kernel_initializer='he_uniform' ,  activation='relu'))

# output layer
model.add(Dense(3, activation='sigmoid'))

# compile model
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9),
                metrics=['accuracy'])

history = model.fit(X_train,
              y_train,
              validation_data=(X_test, y_test),
              batch_size = 1,
              epochs = 125
              )
# Out:
# Epoch 1/125
# 500/500 [==============================] - 3s 5ms/step - loss: 2.9963 - accuracy: 0.5420 - val_loss: 0.9029 - val_accuracy: 0.7060
# Epoch 2/125
# 500/500 [==============================] - 2s 4ms/step - loss: 1.0261 - accuracy: 0.6980 - val_loss: 0.5872 - val_accuracy: 0.8020
# Epoch 3/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.8195 - accuracy: 0.7020 - val_loss: 0.6615 - val_accuracy: 0.7480
# Epoch 4/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.6132 - accuracy: 0.7500 - val_loss: 0.6155 - val_accuracy: 0.7220
# Epoch 5/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.5537 - accuracy: 0.7600 - val_loss: 0.4698 - val_accuracy: 0.8100
# Epoch 6/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4901 - accuracy: 0.7860 - val_loss: 0.4226 - val_accuracy: 0.8180
# Epoch 7/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4833 - accuracy: 0.7920 - val_loss: 0.4412 - val_accuracy: 0.8040
# Epoch 8/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4793 - accuracy: 0.7960 - val_loss: 0.4717 - val_accuracy: 0.8140
# Epoch 9/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4731 - accuracy: 0.7960 - val_loss: 0.4314 - val_accuracy: 0.8320
# Epoch 10/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4468 - accuracy: 0.8000 - val_loss: 0.4303 - val_accuracy: 0.8160
# Epoch 11/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4534 - accuracy: 0.8000 - val_loss: 0.4726 - val_accuracy: 0.8160
# Epoch 12/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4512 - accuracy: 0.8100 - val_loss: 0.4662 - val_accuracy: 0.8080
# Epoch 13/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4417 - accuracy: 0.8060 - val_loss: 0.6891 - val_accuracy: 0.6580
# Epoch 14/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4472 - accuracy: 0.7940 - val_loss: 0.4195 - val_accuracy: 0.8220
# Epoch 15/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4414 - accuracy: 0.8160 - val_loss: 0.4995 - val_accuracy: 0.7580
# Epoch 16/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4417 - accuracy: 0.8080 - val_loss: 0.4187 - val_accuracy: 0.8320
# Epoch 17/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4326 - accuracy: 0.8100 - val_loss: 0.4762 - val_accuracy: 0.8160
# Epoch 18/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4459 - accuracy: 0.8080 - val_loss: 0.4455 - val_accuracy: 0.8260
# Epoch 19/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4349 - accuracy: 0.8080 - val_loss: 0.4184 - val_accuracy: 0.8340
# Epoch 20/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4356 - accuracy: 0.8220 - val_loss: 0.4875 - val_accuracy: 0.7820
# Epoch 21/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0
125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.3976 - accuracy: 0.8220 - val_loss: 0.4426 - val_accuracy: 0.8260
# Epoch 118/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.3886 - accuracy: 0.8100 - val_loss: 0.4741 - val_accuracy: 0.8240
# Epoch 119/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4029 - accuracy: 0.8280 - val_loss: 0.5194 - val_accuracy: 0.7840
# Epoch 120/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.4041 - accuracy: 0.8240 - val_loss: 0.4515 - val_accuracy: 0.8240
# Epoch 121/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4109 - accuracy: 0.8280 - val_loss: 0.4386 - val_accuracy: 0.8180
# Epoch 122/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.3927 - accuracy: 0.8240 - val_loss: 0.4329 - val_accuracy: 0.8160
# Epoch 123/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.3921 - accuracy: 0.8200 - val_loss: 0.4369 - val_accuracy: 0.8260
# Epoch 124/125
# 500/500 [==============================] - 2s 4ms/step - loss: 0.4041 - accuracy: 0.8240 - val_loss: 0.4380 - val_accuracy: 0.8140
# Epoch 125/125
# 500/500 [==============================] - 2s 5ms/step - loss: 0.3934 - accuracy: 0.8320 - val_loss: 0.4540 - val_accuracy: 0.8260

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##### Size =  16

# %% [markdown]
# 10. **Retrain for 16 batch size**

# %%
### START CODE HERE ### 
batch_size = 16

history = fit_model(X_train, y_train, X_test, y_test, batch_size)
###### END CODE HERE
# Out:
# Epoch 1/125
# 32/32 [==============================] - 1s 9ms/step - loss: 2.3299 - accuracy: 0.5020 - val_loss: 1.6971 - val_accuracy: 0.6100
# Epoch 2/125
# 32/32 [==============================] - 0s 5ms/step - loss: 2.3028 - accuracy: 0.6040 - val_loss: 1.5880 - val_accuracy: 0.6480
# Epoch 3/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.8810 - accuracy: 0.6600 - val_loss: 0.5344 - val_accuracy: 0.8040
# Epoch 4/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5726 - accuracy: 0.7480 - val_loss: 0.4902 - val_accuracy: 0.8080
# Epoch 5/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4953 - accuracy: 0.8060 - val_loss: 0.4827 - val_accuracy: 0.8220
# Epoch 6/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5188 - accuracy: 0.7780 - val_loss: 0.4718 - val_accuracy: 0.8080
# Epoch 7/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4843 - accuracy: 0.8020 - val_loss: 0.4723 - val_accuracy: 0.8080
# Epoch 8/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5887 - accuracy: 0.7420 - val_loss: 0.4978 - val_accuracy: 0.8200
# Epoch 9/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4729 - accuracy: 0.8140 - val_loss: 0.4360 - val_accuracy: 0.8220
# Epoch 10/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4560 - accuracy: 0.8100 - val_loss: 0.4617 - val_accuracy: 0.8220
# Epoch 11/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4503 - accuracy: 0.8140 - val_loss: 0.4363 - val_accuracy: 0.8160
# Epoch 12/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4434 - accuracy: 0.8260 - val_loss: 0.4694 - val_accuracy: 0.8060
# Epoch 13/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4448 - accuracy: 0.8080 - val_loss: 0.4504 - val_accuracy: 0.8200
# Epoch 14/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4556 - accuracy: 0.8060 - val_loss: 0.4277 - val_accuracy: 0.8240
# Epoch 15/125
# 32/32 [==============================] - 0s 5ms/step - loss: 0.
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# 10. **What effect does changing batch size have on learning in terms of convergence and fluctuations?**
#
# **Answer:** Increasing batch size decreases fluctuations and the model converges eventually

# %% [markdown]
# #### Learning Rate

# %% [markdown]
# batch size 64

# %% [markdown]
# - **Use same code for build_model above, add an argument learning rate to change learning rate of optmizer**

# %%
def build_model(lr):
    
    ##### YOUR CODE HERE
    model = Sequential()

    # 1st layer
    model.add(Dense(50, kernel_initializer=tf.keras.initializers.HeUniform() ,  activation='relu'))

    # output layer
    model.add(Dense(3, activation='sigmoid' ))

    # compile model
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9),
                   metrics=['accuracy'])
    
    return model

# %% [markdown]
# ##### LR =  0.00001

# %% [markdown]
# 10. **Retrain for 0.00001 LR**

# %%
### START CODE HERE ### ()
# Print the model summary
model = build_model(0.00001)
history = model.fit(X_train,
              y_train,
              validation_data=(X_test, y_test),
              batch_size = 64,
              epochs = 125
              )
# Out:
# Epoch 1/125
# 8/8 [==============================] - 0s 24ms/step - loss: 1.3428 - accuracy: 0.4520 - val_loss: 1.3172 - val_accuracy: 0.4620
# Epoch 2/125
# 8/8 [==============================] - 0s 12ms/step - loss: 1.3174 - accuracy: 0.4540 - val_loss: 1.2864 - val_accuracy: 0.4660
# Epoch 3/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.2808 - accuracy: 0.4600 - val_loss: 1.2536 - val_accuracy: 0.4760
# Epoch 4/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.2464 - accuracy: 0.4660 - val_loss: 1.2223 - val_accuracy: 0.4980
# Epoch 5/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.2116 - accuracy: 0.4840 - val_loss: 1.1972 - val_accuracy: 0.5020
# Epoch 6/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.1864 - accuracy: 0.4860 - val_loss: 1.1754 - val_accuracy: 0.5040
# Epoch 7/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1647 - accuracy: 0.4860 - val_loss: 1.1580 - val_accuracy: 0.5080
# Epoch 8/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.1462 - accuracy: 0.4820 - val_loss: 1.1445 - val_accuracy: 0.5100
# Epoch 9/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1318 - accuracy: 0.4820 - val_loss: 1.1335 - val_accuracy: 0.5060
# Epoch 10/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1199 - accuracy: 0.4820 - val_loss: 1.1239 - val_accuracy: 0.5080
# Epoch 11/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1106 - accuracy: 0.4860 - val_loss: 1.1150 - val_accuracy: 0.5060
# Epoch 12/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1019 - accuracy: 0.4840 - val_loss: 1.1068 - val_accuracy: 0.5080
# Epoch 13/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.0934 - accuracy: 0.4840 - val_loss: 1.0988 - val_accuracy: 0.5040
# Epoch 14/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.0859 - accuracy: 0.4860 - val_loss: 1.0912 - val_accuracy: 0.5040
# Epoch 15/125
125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.7986 - accuracy: 0.5480 - val_loss: 0.7648 - val_accuracy: 0.5840
# Epoch 124/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7979 - accuracy: 0.5520 - val_loss: 0.7641 - val_accuracy: 0.5840
# Epoch 125/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7974 - accuracy: 0.5520 - val_loss: 0.7634 - val_accuracy: 0.5860

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##### LR =  0.001

# %% [markdown]
# 10. **Retrain for 0.001 LR**

# %%
### START CODE HERE ### ()
model = build_model(0.001)
history = model.fit(X_train,
              y_train,
              validation_data=(X_test, y_test),
              batch_size = 64,
              epochs = 125
              )
# Out:
# Epoch 1/125
# 8/8 [==============================] - 0s 26ms/step - loss: 3.7631 - accuracy: 0.3600 - val_loss: 3.7483 - val_accuracy: 0.3700
# Epoch 2/125
# 8/8 [==============================] - 0s 10ms/step - loss: 3.3274 - accuracy: 0.4080 - val_loss: 1.6071 - val_accuracy: 0.3640
# Epoch 3/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.2944 - accuracy: 0.4320 - val_loss: 1.2214 - val_accuracy: 0.5340
# Epoch 4/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.2606 - accuracy: 0.5440 - val_loss: 1.0687 - val_accuracy: 0.5880
# Epoch 5/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9783 - accuracy: 0.5980 - val_loss: 0.8131 - val_accuracy: 0.6580
# Epoch 6/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8737 - accuracy: 0.5860 - val_loss: 0.7857 - val_accuracy: 0.6180
# Epoch 7/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.7996 - accuracy: 0.5900 - val_loss: 0.7182 - val_accuracy: 0.6400
# Epoch 8/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7752 - accuracy: 0.6000 - val_loss: 0.7090 - val_accuracy: 0.6440
# Epoch 9/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7499 - accuracy: 0.6240 - val_loss: 0.6763 - val_accuracy: 0.6940
# Epoch 10/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7335 - accuracy: 0.6340 - val_loss: 0.6715 - val_accuracy: 0.7000
# Epoch 11/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7236 - accuracy: 0.6480 - val_loss: 0.6612 - val_accuracy: 0.6780
# Epoch 12/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7283 - accuracy: 0.6580 - val_loss: 0.6540 - val_accuracy: 0.6860
# Epoch 13/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7299 - accuracy: 0.6400 - val_loss: 0.6884 - val_accuracy: 0.7180
# Epoch 14/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.7229 - accuracy: 0.6520 - val_loss: 0.6346 - val_accuracy: 0.7160
# Epoch 15/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6928 - accuracy: 0.6680 - val_loss: 0.6331 - val_accuracy: 0.6940
# Epoch 16/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6985 - accuracy: 0.6640 - val_loss: 0.6239 - val_accuracy: 0.7060
# Epoch 17/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6855 - accuracy: 0.6720 - val_loss: 0.6217 - val_accuracy: 0.7160
# Epoch 18/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6873 - accuracy: 0.6640 - val_loss: 0.6240 - val_accuracy: 0.7220
# Epoch 19/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6743 - accuracy: 0.6760 - val_loss: 0.6179 - val_accuracy: 0.7100
# Epoch 20/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.6560 - val_loss: 0.6835 - val_accuracy: 0.7200
# Epoch 21/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7102 - accuracy: 0.6640 - val_loss: 0.6367 - val_accuracy: 0.7480
# Epoch 22/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.
125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5434 - accuracy: 0.7620 - val_loss: 0.5018 - val_accuracy: 0.8220
# Epoch 114/125
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5327 - accuracy: 0.7880 - val_loss: 0.5001 - val_accuracy: 0.8160
# Epoch 115/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5296 - accuracy: 0.7860 - val_loss: 0.4991 - val_accuracy: 0.8220
# Epoch 116/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5252 - accuracy: 0.7860 - val_loss: 0.5028 - val_accuracy: 0.8240
# Epoch 117/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5338 - accuracy: 0.7720 - val_loss: 0.5024 - val_accuracy: 0.8220
# Epoch 118/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5337 - accuracy: 0.7780 - val_loss: 0.5058 - val_accuracy: 0.8220
# Epoch 119/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5270 - accuracy: 0.7800 - val_loss: 0.5085 - val_accuracy: 0.8220
# Epoch 120/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5256 - accuracy: 0.7920 - val_loss: 0.4961 - val_accuracy: 0.8060
# Epoch 121/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5242 - accuracy: 0.7860 - val_loss: 0.4983 - val_accuracy: 0.8240
# Epoch 122/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5259 - accuracy: 0.7840 - val_loss: 0.4940 - val_accuracy: 0.8200
# Epoch 123/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5289 - accuracy: 0.7680 - val_loss: 0.5069 - val_accuracy: 0.8280
# Epoch 124/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5233 - accuracy: 0.7820 - val_loss: 0.4975 - val_accuracy: 0.8260
# Epoch 125/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5207 - accuracy: 0.7880 - val_loss: 0.4920 - val_accuracy: 0.8140

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##### LR =  0.1

# %% [markdown]
# 10. **Retrain for 0.1 LR**

# %%
### START CODE HERE ### ()
model = build_model(0.1)
history = model.fit(X_train,
              y_train,
              validation_data=(X_test, y_test),
              batch_size = 64,
              epochs = 125
              )
# Out:
# Epoch 1/125
# 8/8 [==============================] - 0s 24ms/step - loss: 14.8790 - accuracy: 0.3640 - val_loss: 4.1414 - val_accuracy: 0.4500
# Epoch 2/125
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0113 - accuracy: 0.3400 - val_loss: 2.5879 - val_accuracy: 0.4360
# Epoch 3/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.6680 - accuracy: 0.4280 - val_loss: 1.3337 - val_accuracy: 0.5280
# Epoch 4/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.3452 - accuracy: 0.5080 - val_loss: 1.2398 - val_accuracy: 0.5840
# Epoch 5/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.2916 - accuracy: 0.5600 - val_loss: 1.1830 - val_accuracy: 0.6240
# Epoch 6/125
# 8/8 [==============================] - 0s 7ms/step - loss: 1.2060 - accuracy: 0.5960 - val_loss: 1.1513 - val_accuracy: 0.6540
# Epoch 7/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.1155 - accuracy: 0.6340 - val_loss: 1.0229 - val_accuracy: 0.6400
# Epoch 8/125
# 8/8 [==============================] - 0s 8ms/step - loss: 1.0486 - accuracy: 0.5980 - val_loss: 0.9240 - val_accuracy: 0.6420
# Epoch 9/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.9871 - accuracy: 0.6100 - val_loss: 0.8691 - val_accuracy: 0.6720
# Epoch 10/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0
125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4308 - accuracy: 0.8180 - val_loss: 0.4134 - val_accuracy: 0.8300
# Epoch 101/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4078 - accuracy: 0.8260 - val_loss: 0.4907 - val_accuracy: 0.7860
# Epoch 102/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4434 - accuracy: 0.8080 - val_loss: 0.4387 - val_accuracy: 0.8040
# Epoch 103/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4378 - accuracy: 0.8180 - val_loss: 0.4239 - val_accuracy: 0.8300
# Epoch 104/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4226 - accuracy: 0.8260 - val_loss: 0.4426 - val_accuracy: 0.8260
# Epoch 105/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4567 - accuracy: 0.7820 - val_loss: 0.4371 - val_accuracy: 0.8160
# Epoch 106/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4711 - accuracy: 0.8000 - val_loss: 0.4223 - val_accuracy: 0.8360
# Epoch 107/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5042 - accuracy: 0.7840 - val_loss: 0.4636 - val_accuracy: 0.8080
# Epoch 108/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4351 - accuracy: 0.8220 - val_loss: 0.5083 - val_accuracy: 0.7960
# Epoch 109/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5314 - accuracy: 0.7940 - val_loss: 0.4208 - val_accuracy: 0.8340
# Epoch 110/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5398 - accuracy: 0.7680 - val_loss: 0.5289 - val_accuracy: 0.7940
# Epoch 111/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5116 - accuracy: 0.7940 - val_loss: 0.5853 - val_accuracy: 0.7780
# Epoch 112/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5763 - accuracy: 0.7460 - val_loss: 0.5080 - val_accuracy: 0.8040
# Epoch 113/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5115 - accuracy: 0.7820 - val_loss: 0.5023 - val_accuracy: 0.8100
# Epoch 114/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4704 - accuracy: 0.7940 - val_loss: 0.4605 - val_accuracy: 0.8000
# Epoch 115/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4763 - accuracy: 0.7760 - val_loss: 0.6012 - val_accuracy: 0.7120
# Epoch 116/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4920 - accuracy: 0.7740 - val_loss: 0.4810 - val_accuracy: 0.8280
# Epoch 117/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4826 - accuracy: 0.8020 - val_loss: 0.4358 - val_accuracy: 0.8300
# Epoch 118/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5087 - accuracy: 0.7560 - val_loss: 0.4593 - val_accuracy: 0.8040
# Epoch 119/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4818 - accuracy: 0.7760 - val_loss: 0.5406 - val_accuracy: 0.7600
# Epoch 120/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5260 - accuracy: 0.7680 - val_loss: 0.6200 - val_accuracy: 0.7560
# Epoch 121/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5251 - accuracy: 0.7840 - val_loss: 0.6185 - val_accuracy: 0.7560
# Epoch 122/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5814 - accuracy: 0.7500 - val_loss: 0.4633 - val_accuracy: 0.8000
# Epoch 123/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4455 - accuracy: 0.8080 - val_loss: 0.4465 - val_accuracy: 0.8180
# Epoch 124/125
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4209 - accuracy: 0.8120 - val_loss: 0.4548 - val_accuracy: 0.8060
# Epoch 125/125
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4424 - accuracy: 0.7960 - val_loss: 0.4316 - val_accuracy: 0.8180

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# 10. **What effect does changing learning rate have on learning?**
#
# **Answer:** If the learning rate is set too low, training will progress very slowly as the model is making very tiny updates to the weights in the network. However, if the learning rate is set too high, it can cause undesirable divergent behavior in our loss function
